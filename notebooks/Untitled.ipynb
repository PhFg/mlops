# %%
cat ~/projetos/mlops/.env.example
# Out:
# # MLflow Configuration
# MLFLOW_TRACKING_URI=http://localhost:5010
#
# # Object Storage Configuration (Zenko CloudServer - Apache 2.0)
# AWS_ACCESS_KEY_ID=user
# AWS_SECRET_ACCESS_KEY=password
# MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
#
# # Database Configuration
# DATABASE_URL=postgresql://mlops_user:admin@localhost:5434/mlops_db
# POSTGRES_USER=user
# POSTGRES_PASSWORD=password
# POSTGRES_DB=db
#
# # Application Settings
# APP_NAME=MLOps Lab
# ENVIRONMENT=development
# DEBUG=True
# ENV=PROD

# %%
cp ~/projetos/mlops/.env.example ~/projetos/mlops/.env

# %%
# !rm -rf ~/projetos/mlops/notebooks/mlruns
# !rm -f ~/projetos/mlops/notebooks/mlflow.db
